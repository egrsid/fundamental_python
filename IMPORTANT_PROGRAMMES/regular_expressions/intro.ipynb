# %%
import re
s = '12 1a3 2a2-a3-a-2 d c A'

# %% [markdown]
# ## Введение

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pattern = r'12'  # просто совпадения по определенному наботу символов

# %%
pattern = r'[123]a[231]'  # то, что в [] - алфавит для поиска ->
# он может найти выражение, где 1)1или2или3 2) a 3) 2или3или1

# %%
pattern = r'[1-3]a[1-3]'  # то же самое, что и в предыдущем примере, 
# но только экономит место (числа с 1 до 3)

# %%
pattern = r'[^1-3]'  # отрицание; выделяет все символы, кроме тех, что после "^"

# %%
pattern = r'[a-fA-F]'  # то же самое с алфавитом 
# (прямо подряд, чтобы перебирались и заглавные, и строчные буквы)
